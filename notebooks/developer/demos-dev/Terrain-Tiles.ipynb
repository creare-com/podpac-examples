# %%
# For interactive plots, comment the next line
# %pylab inline
# For interactive plots, uncomment the next line
# %pylab ipympl
import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Introduction
#
# This notebook demonstrates how to access a repository of terrain data stored on S3.
#
# Specifically, this example will demonstrate:
#
# * Retrieving a subset of data over arbitrary coordinates
# * Plotting retrieved data with state boundaries overlaid using the `cartopy` library
# * How to retrieve a single file as stored on S3

# %% [markdown]
# # Terrain Tiles
#
# A global dataset providing bare-earth terrain heights, tiled for easy usage and provided on S3.
#
# Source: https://registry.opendata.aws/terrain-tiles/
#
# - Description
#     - Gridded elevation tiles
# - Resource type
#     - S3 Bucket
# - Amazon Resource Name (ARN)
#     - `arn:aws:s3:::elevation-tiles-prod`
# - AWS Region
#     - `us-east-1`

# %% [markdown]
# ## TerrainTiles
#
# Select multiple terrain tiles based on arbitrary podpac Coordinates

# %%
from podpac.datalib.terraintiles import TerrainTiles
from podpac import Coordinates, clinspace

# %%
# create terrain tiles node
node = TerrainTiles(tile_format='geotiff', zoom=8)

# create coordinates to get tiles
c = Coordinates([clinspace(40, 43, 1000), clinspace(-76, -72, 1000)], dims=['lat', 'lon'])

# evaluate node
o = node.eval(c)
# Out:
# INFO:podpac.datalib.terraintiles:Downloading S3 fileobj: elevation-tiles-prod/geotiff/8/75/94.tif
# INFO:podpac.datalib.terraintiles:Downloading S3 fileobj: elevation-tiles-prod/geotiff/8/73/94.tif
# INFO:podpac.datalib.terraintiles:Downloading S3 fileobj: elevation-tiles-prod/geotiff/8/76/94.tif
# INFO:podpac.datalib.terraintiles:Downloading S3 fileobj: elevation-tiles-prod/geotiff/8/74/94.tif
# INFO:podpac.datalib.terraintiles:Downloading S3 fileobj: elevation-tiles-prod/geotiff/8/75/95.tif
# INFO:podpac.datalib.terraintiles:Downloading S3 fileobj: elevation-tiles-prod/geotiff/8/76/95.tif
# INFO:podpac.datalib.terraintiles:Downloading S3 fileobj: elevation-tiles-prod/geotiff/8/73/95.tif
# INFO:podpac.datalib.terraintiles:Downloading S3 fileobj: elevation-tiles-prod/geotiff/8/74/95.tif
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support open option MODE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support open option MODE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support open option MODE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support open option MODE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support open option MODE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support open option MODE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support open option MODE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support open option MODE
# INFO:podpac.datalib.terraintiles:Downloading S3 fileobj: elevation-tiles-prod/geotiff/8/73/96.tif
# INFO:podpac.datalib.terraintiles:Downloading S3 fileobj: elevation-tiles-prod/geotiff/8/74/96.tif
# INFO:podpac.datalib.terraintiles:Downloading S3 fileobj: elevation-tiles-prod/geotiff/8/75/96.tif
# INFO:podpac.datalib.terraintiles:Downloading S3 fileobj: elevation-tiles-prod/geotiff/8/76/96.tif
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support open option MODE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support open option MODE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support open option MODE
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support open option MODE

# %%
o
# Out:
# <xarray.UnitsDataArray (lat: 1000, lon: 1000)>
# array([[172., 190., 206., ...,  nan,  nan,  nan],
#        [160., 158., 164., ...,  nan,  nan,  nan],
#        [142., 141., 144., ...,  nan,  nan,  nan],
#        ...,
#        [233., 224., 202., ..., 424., 388., 333.],
#        [212., 211., 196., ..., 415., 375., 333.],
#        [207., 204., 198., ..., 378., 355., 331.]])
# Coordinates:
#   * lat      (lat) float64 40.0 40.0 40.01 40.01 40.01 ... 42.99 42.99 43.0 43.0
#   * lon      (lon) float64 -76.0 -76.0 -75.99 -75.99 ... -72.01 -72.0 -72.0
# Attributes:
#     layer_style:  <podpac.core.style.Style object at 0x0000029E8FDBA550>
#     crs:          EPSG:4326

# %%
# plot the elevation
fig = plt.figure(dpi=90)
o.plot()
pass

# %% [markdown]
# # Plotting results with `cartopy`

# %%
# plot with state boundaries data
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# create the figure
fig = plt.figure(dpi=90)
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

# set bounds using output
lat_bounds = [o['lat'].min(), o['lat'].max()]
lon_bounds = [o['lon'].min(), o['lon'].max()]
ax.set_extent([lon_bounds[0], lon_bounds[1], lat_bounds[0], lat_bounds[1]], crs=ccrs.PlateCarree())

# ax.add_feature(rivers, edgecolor='red', linewidth=2)
states_provinces = cfeature.NaturalEarthFeature(
    category='cultural',
    name='admin_1_states_provinces_lines',
    scale='50m',
    facecolor='none')
ax.add_feature(states_provinces, edgecolor='gray')

o.plot()
pass

# %% [markdown]
# # Download source files locally

# %%
# download active source files locally
# you must evaluate the node at coordinates for sources to be defined
node.download()

# %% [markdown]
# ## Retrieving a single file using `TerrainTilesSource`
#
# Load one individual tile from the TerrainTiles set

# %%
from podpac.datalib.terraintiles import TerrainTilesSource

# %%
# select a single source from S3 bucket url  
# see `terraintiles.get_tile_urls(...)` below for getting tile endpoints
node = TerrainTilesSource(source='terraintiles/elevation-tiles-prod/geotiff/8/73/94.tif')

# evaluate at its native coordinates
c = node.native_coordinates.transform('epsg:4326')
output = node.eval(c)
# Out:
# WARNING:rasterio._env:CPLE_NotSupported in driver GTiff does not support open option MODE

# %%
# plot the gridded output data
output.plot()
pass

# %%
# plot the original raster image using the
# `node` reference to the rasterio dataset
plt.imshow(node.dataset.read(1))
pass

# %%
# download active source files locally
# you must evaluate the node at coordinates for sources to be defined
node.download()
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\podpac\lib\site-packages\s3fs\core.py in info(self, path, version_id, refresh, **kwargs)
#     525             out = self._call_s3(self.s3.head_object, kwargs, Bucket=bucket,
# --> 526                                 Key=key, **self.req_kw)
#     527             return {
#
# ~\AppData\Local\Continuum\anaconda3\envs\podpac\lib\site-packages\s3fs\core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     194                                                        **kwargs)
# --> 195         return method(**additional_kwargs)
#     196
#
# ~\AppData\Local\Continuum\anaconda3\envs\podpac\lib\site-packages\botocore\client.py in _api_call(self, *args, **kwargs)
#     319             # The "self" in this scope is referring to the BaseClient.
# --> 320             return self._make_api_call(operation_name, kwargs)
#     321
#
# ~\AppData\Local\Continuum\anaconda3\envs\podpac\lib\site-packages\botocore\client.py in _make_api_call(self, operation_name, api_params)
#     623             error_class = self.exceptions.from_code(error_code)
# --> 624             raise error_class(parsed_response, operation_name)
#     625         else:
#
# ClientError: An error occurred (404) when calling the HeadObject operation: Not Found
#
# The above exception was the direct cause of the following exception:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-8b433dc5c1d3> in <module>()
#       1 # download active source files locally
#       2 # you must evaluate the node at coordinates for sources to be defined
# ----> 3 node.download()
#
# c:\repositories\podpac\podpac\podpac\datalib\terraintiles.py in download(self, path)
#     152         # download the file
#     153         _logger.debug("Downloading terrain tile {} to filepath: {}".format(self.source, filepath))
# --> 154         _s3.get(self.source, filepath)
#     155
#     156 class TerrainTiles(OrderedCompositor):
#
# ~\AppData\Local\Continuum\anaconda3\envs\podpac\lib\site-packages\s3fs\core.py in get(self, path, filename, **kwargs)
#     833     def get(self, path, filename, **kwargs):
#     834         """ Stream data from file at path to local filename """
# --> 835         with self.open(path, 'rb', **kwargs) as f:
#     836             with open(filename, 'wb') as f2:
#     837                 while True:
#
# ~\AppData\Local\Continuum\anaconda3\envs\podpac\lib\site-packages\s3fs\core.py in open(self, path, mode, block_size, acl, version_id, fill_cache, encoding, **kwargs)
#     350         fdesc = S3File(self, path, mode2, block_size=block_size, acl=acl,
#     351                        version_id=version_id, fill_cache=fill_cache,
# --> 352                        s3_additional_kwargs=kw)
#     353         if 'b' in mode:
#     354             return fdesc
#
# ~\AppData\Local\Continuum\anaconda3\envs\podpac\lib\site-packages\s3fs\core.py in __init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs)
#    1208         else:
#    1209             try:
# -> 1210                 info = self.info()
#    1211                 self.size = info['Size']
#    1212                 if self.s3.version_aware:
#
# ~\AppData\Local\Continuum\anaconda3\envs\podpac\lib\site-packages\s3fs\core.py in info(self, **kwargs)
#    1226         refresh = self.s3.version_aware
#    1227         return self.s3.info(self.path, version_id=self.version_id,
# -> 1228                             refresh=refresh, **kwargs)
#    1229
#    1230     def metadata(self, refresh=False, **kwargs):
#
# ~\AppData\Local\Continuum\anaconda3\envs\podpac\lib\site-packages\s3fs\core.py in info(self, path, version_id, refresh, **kwargs)
#     535         except (ClientError, ParamValidationError) as e:
#     536             logger.debug("Failed to head path %s", path, exc_info=True)
# --> 537             raise_from(FileNotFoundError(path), e)
#     538
#     539     def object_version_info(self, path, **kwargs):
#
# ~\AppData\Local\Continuum\anaconda3\envs\podpac\lib\site-packages\six.py in raise_from(value, from_value)
#
# FileNotFoundError: terraintiles/elevation-tiles-prod/geotiff/8/73/94.tif

# %% [markdown]
# ## Utilities

# %%
from podpac.datalib import terraintiles
from podpac.coordinates import Coordinates, clinspace

# %%
# available tile formats
terraintiles.TILE_FORMATS

# %%
# get all tile urls for tile format ('geotiff') certain zoom level (1)
terraintiles.get_tile_urls('geotiff', 1)

# %%
# create coordinates for region
c = Coordinates([clinspace(43, 40, 1000), clinspace(-73, -72, 1000)], dims=['lat', 'lon'])

# get all tile urls for tile format ('geotiff') certain zoom level (9) within coordinates
terraintiles.get_tile_urls('geotiff', 9, coordinates=c)
